# %% [markdown]
# # SET A

# %%
import pandas as pd
df=pd.DataFrame(columns=['Name','Age','Percentage'])
df.loc[0]=['Om',17,78.0]
df.loc[1]=['sai',17,77.5]
df.loc[2]=['Ram',67,76.8]
df.loc[3]=['Sham',56,89.6]
df.loc[4]=['Ammu',78,90.8]
df.loc[5]=['Shonnuu',45,76.4]
df.loc[6]=['Sita',34,67.4]
df.loc[7]=['Gita',38,87.6]
df.loc[8]=['Nita',34,90.5]
df.loc[9]=['Smita',75,99.7]
df
# Out:
#       Name  Age  Percentage
# 0       Om   17        78.0
# 1      sai   17        77.5
# 2      Ram   67        76.8
# 3     Sham   56        89.6
# 4     Ammu   78        90.8
# 5  Shonnuu   45        76.4
# 6     Sita   34        67.4
# 7     Gita   38        87.6
# 8     Nita   34        90.5
# 9    Smita   75        99.7

# %%
df.shape#shape ,no. rows and no. columns
# Out:
# (10, 3)

# %%
df.dtypes #datatypes
# Out:
# Name           object
# Age             int64
# Percentage    float64
# dtype: object

# %%
df.info()#feature name and discription
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         10 non-null     int64
#  2   Percentage  10 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
#basic statistical of the data
df.describe()
# Out:
#              Age  Percentage
# count  10.000000   10.000000
# mean   46.100000   83.430000
# std    22.213359    9.657818
# min    17.000000   67.400000
# 25%    34.000000   76.975000
# 50%    41.500000   82.800000
# 75%    64.250000   90.275000
# max    78.000000   99.700000

# %%
#add new column with duplicate and missing value add newcolumn
df.loc[10]=['Ram',67,None]
df.loc[11]=['Sai',34,90.9]
df.loc[12]=[None,None,None]
df.loc[13]=['Ammu',17,67.8]
df.loc[14]=['Shonnu',None,99.0]
df["Remark"]=None
df
# Out:
#        Name   Age  Percentage Remark
# 0        Om  17.0        78.0   None
# 1       sai  17.0        77.5   None
# 2       Ram  67.0        76.8   None
# 3      Sham  56.0        89.6   None
# 4      Ammu  78.0        90.8   None
# 5   Shonnuu  45.0        76.4   None
# 6      Sita  34.0        67.4   None
# 7      Gita  38.0        87.6   None
# 8      Nita  34.0        90.5   None
# 9     Smita  75.0        99.7   None
# 10      Ram  67.0         NaN   None
# 11      Sai  34.0        90.9   None
# 12     None   NaN         NaN   None
# 13     Ammu  17.0        67.8   None
# 14   Shonnu   NaN        99.0   None

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
df.isnull()
# Out:
#      Name    Age  Percentage  Remark
# 0   False  False       False    True
# 1   False  False       False    True
# 2   False  False       False    True
# 3   False  False       False    True
# 4   False  False       False    True
# 5   False  False       False    True
# 6   False  False       False    True
# 7   False  False       False    True
# 8   False  False       False    True
# 9   False  False       False    True
# 10  False  False        True    True
# 11  False  False       False    True
# 12   True   True        True    True
# 13  False  False       False    True
# 14  False   True       False    True

# %%
df.drop("Remark",axis=1,inplace=True)
df
# Out:
#        Name   Age  Percentage
# 0        Om  17.0        78.0
# 1       sai  17.0        77.5
# 2       Ram  67.0        76.8
# 3      Sham  56.0        89.6
# 4      Ammu  78.0        90.8
# 5   Shonnuu  45.0        76.4
# 6      Sita  34.0        67.4
# 7      Gita  38.0        87.6
# 8      Nita  34.0        90.5
# 9     Smita  75.0        99.7
# 10      Ram  67.0         NaN
# 11      Sai  34.0        90.9
# 12     None   NaN         NaN
# 13     Ammu  17.0        67.8
# 14   Shonnu   NaN        99.0

# %%
df.fillna("NULL",inplace=True)
df
# Out:
#                   Name                 Age          Percentage
# 0                   Om                17.0                78.0
# 1                  sai                17.0                77.5
# 2                  Ram                67.0                76.8
# 3                 Sham                56.0                89.6
# 4                 Ammu                78.0                90.8
# 5              Shonnuu                45.0                76.4
# 6                 Sita                34.0                67.4
# 7                 Gita                38.0                87.6
# 8                 Nita                34.0                90.5
# 9                Smita                75.0                99.7
# 10                 Ram                67.0  No Values Avilabel
# 11                 Sai                34.0                90.9
# 12  No Values Avilabel  No Values Avilabel  No Values Avilabel
# 13                Ammu                17.0                67.8
# ...

# %%
import matplotlib.pyplot as plt
df.plot(x="Name",y="Percentage")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
df.plot(kind="scatter",x="Name",y="Percentage")
plt.show()

# %%
import seaborn as sns
sns.countplot(df['Percentage'])
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sans
sans.countplot(df['Name'])
# Out:
# <Axes: xlabel='count', ylabel='Name'>

# %%
import matplotlib.pyplot as plt
#plot Name for all the entries
plt.plot(df.Name,df['Percentage'],"r--")
plt.show()

# %%
#plot Percentage for all entries
plt.plot(df.Percentage,df['Name'],"g--")
plt.show()

# %% [markdown]
# # SETB

# %%
import pandas as pd
df=pd.read_csv("/home/kalyani/DS/archive/SOCR-HeightWeight.csv")
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
df.head(10)
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971
# 5      6        68.69784        123.3024
# 6      7        69.80204        141.4947
# 7      8        70.01472        136.4623
# 8      9        67.90265        112.3723
# 9     10        66.78236        120.6672

# %%
df.tail(10)
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 24990  24991        69.97767        125.3672
# 24991  24992        71.91656        128.2840
# 24992  24993        70.96218        146.1936
# 24993  24994        66.19462        118.7974
# 24994  24995        67.21126        127.6603
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742

# %%
df.sample(20)
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 14171  14172        65.07798        131.2823
# 9734    9735        66.15786        134.1293
# 7011    7012        67.80572        138.3332
# 7333    7334        73.01042        156.0944
# 3056    3057        70.23276        137.7724
# 4430    4431        69.91503        119.8377
# 1082    1083        70.72387        135.1996
# 16485  16486        70.90585        132.9018
# 9323    9324        69.35355        128.9771
# 24124  24125        68.74365        118.5769
# 19756  19757        69.08878        123.8895
# 11009  11010        68.97817        138.3514
# 3651    3652        68.90210        141.0105
# 3889    3890        64.48357        117.4963
# 19404  19405        68.78039        117.1408
# 13398  13399        63.44163        115.5336
# 12711  12712        66.19854        113.9223
# 3045    3046        66.23601        123.6908
# 7753    7754        69.24298        125.4025
# 678      679        69.35781        134.4605

# %%
df.dtypes
# Out:
# Index               int64
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %%
df.shape
# Out:
# (25000, 3)

# %%
df.size
# Out:
# 75000

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
df.isnull()
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0      False           False           False
# 1      False           False           False
# 2      False           False           False
# 3      False           False           False
# 4      False           False           False
# ...      ...             ...             ...
# 24995  False           False           False
# 24996  False           False           False
# 24997  False           False           False
# 24998  False           False           False
# 24999  False           False           False
#
# [25000 rows x 3 columns]

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24995    False
# 24996    False
# 24997    False
# 24998    False
# 24999    False
# Length: 25000, dtype: bool

# %%
df["BMI"]=df['Weight(Pounds)']/df['Height(Inches)']*df['Height(Inches)']
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)       BMI
# 0          1        65.78331        112.9925  112.9925
# 1          2        71.51521        136.4873  136.4873
# 2          3        69.39874        153.0269  153.0269
# 3          4        68.21660        142.3354  142.3354
# 4          5        67.78781        144.2971  144.2971
# ...      ...             ...             ...       ...
# 24995  24996        69.50215        118.0312  118.0312
# 24996  24997        64.54826        120.1932  120.1932
# 24997  24998        64.69855        118.2655  118.2655
# 24998  24999        67.52918        132.2682  132.2682
# 24999  25000        68.87761        124.8742  124.8742
#
# [25000 rows x 4 columns]

# %%
df.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)           BMI
# count  25000.000000    25000.000000    25000.000000  25000.000000
# mean   12500.500000       67.993114      127.079421    127.079421
# std     7217.022701        1.901679       11.660898     11.660898
# min        1.000000       60.278360       78.014760     78.014760
# 25%     6250.750000       66.704397      119.308675    119.308675
# 50%    12500.500000       67.995700      127.157750    127.157750
# 75%    18750.250000       69.272958      134.892850    134.892850
# max    25000.000000       75.152800      170.924000    170.924000

# %%
import numpy as np
print(np.max(df['BMI']))
# Out:
# 170.924

# %%
print(np.min(df['BMI']))
# Out:
# 78.01476

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df.plot(kind="scatter",x="Height(Inches)",y="Weight(Pounds)")
plt.show()
